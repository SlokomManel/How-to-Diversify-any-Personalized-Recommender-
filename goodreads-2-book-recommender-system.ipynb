# %% [markdown]
# # Books Recommender System

# %% [markdown]
# ![](http://labs.criteo.com/wp-content/uploads/2017/08/CustomersWhoBought3.jpg)

# %% [markdown]
# This is the second part of my project on Book Data Analysis and Recommendation Systems.
#
# In my first notebook ([The Story of Book](https://www.kaggle.com/omarzaghlol/goodreads-1-the-story-of-book/)), I attempted at narrating the story of book by performing an extensive exploratory data analysis on Books Metadata collected from Goodreads.
#
# In this notebook, I will attempt at implementing a few recommendation algorithms (Basic Recommender, Content-based and Collaborative Filtering) and try to build an ensemble of these models to come up with our final recommendation system.

# %% [markdown]
# # What's in this kernel?

# %% [markdown]
# - [Importing Libraries and Loading Our Data](#1)
# - [Clean the dataset](#2)
# - [Simple Recommender](#3)
#     - [Top Books](#4)
#     - [Top "Genres" Books](#5)
# - [Content Based Recommender](#6)
#     - [Cosine Similarity](#7)
#     - [Popularity and Ratings](#8)
# - [Collaborative Filtering](#9)
#     - [User Based](#10)
#     - [Item Based](#11)
# - [Hybrid Recommender](#12)
# - [Conclusion](#13)
# - [Save Model](#14)

# %% [markdown]
# # Importing Libraries and Loading Our Data <a id="1"></a> <br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
######
from lenskit import batch, topn
import lenskit.crossfold as xf
import warnings
warnings.filterwarnings('ignore')
# !pip install lenskit_tf
from lenskit import topn, util
from lenskit.algorithms import Recommender, item_knn, user_knn, als, tf
from lenskit.algorithms import basic

# %%
books = pd.read_csv('goodbook/books.csv')
ratings = pd.read_csv('goodbook/ratings.csv')
book_tags = pd.read_csv('goodbook/book_tags.csv')
tags = pd.read_csv('goodbook/tags.csv')

# %% [markdown]
# # Start with Book tags

# %%
genres = ["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics",
          "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction",
          "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror",
          "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal",
          "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction", 
          "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

genres = list(map(str.lower, genres))
genres[:4]
# Out:
# ['art', 'biography', 'business', 'chick lit']

# %%
available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]

# %%
available_genres_books = book_tags[book_tags.tag_id.isin(available_genres.tag_id)]
print('There are {} books that are tagged with above genres'.format(available_genres_books.shape[0]))
# Out:
# There are 60573 books that are tagged with above genres

# %%
available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values
available_genres_books.head()
# Out:
#     goodreads_book_id  tag_id  count       genre
# 1                   1   11305  37174     fantasy
# 5                   1   11743   9954     fiction
# 25                  1    7457    958    classics
# 38                  1   22973    673  paranormal
# 52                  1   20939    465     mystery

# %%
np.sort(ratings.groupby('user_id')['rating'].count())[::-1]
# Out:
# array([200, 200, 199, ...,   2,   2,   2])

# %%
dup_ratings = ratings.drop_duplicates(keep='first')
dup_ratings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [980112 rows x 3 columns]

# %%
print (len (dup_ratings.user_id.unique()))
print(len (dup_ratings.book_id.unique()))
# Out:
# 53424
# 10000

# %%
available_genres_books = book_tags[book_tags.tag_id.isin(available_genres.tag_id)]
available_genres_books ["book_id"] = available_genres_books ["goodreads_book_id"]
available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values

# Merge the DataFrames based on the 'book_id' column
genres_ratings = dup_ratings.merge(available_genres_books, on='book_id', how='inner')
genres_ratings
# Out:
#         book_id  user_id  rating  goodreads_book_id  tag_id  count  \
# 0             1      314       5                  1   11305  37174
# 1             1      314       5                  1   11743   9954
# 2             1      314       5                  1    7457    958
# 3             1      314       5                  1   22973    673
# 4             1      314       5                  1   20939    465
# ...         ...      ...     ...                ...     ...    ...
# 496543     9998    53249       5               9998   14821     21
# 496544     9998    53249       5               9998    8055     18
# 496545     9998    53249       5               9998   23471     17
# 496546     9998    53249       5               9998   10210      7
# 496547     9998    53249       5               9998   20939      6
#
#                genre
# 0            fantasy
# 1            fiction
# 2           classics
# 3         paranormal
# 4            mystery
# ...              ...
# 496543        horror
# 496544  contemporary
# 496545    philosophy
# 496546        ebooks
# 496547       mystery
#
# [496548 rows x 7 columns]

# %%
df_fil = genres_ratings[['user_id', 'book_id', 'rating', 'genre']]
df_fil
# Out:
#         user_id  book_id  rating         genre
# 0           314        1       5       fantasy
# 1           314        1       5       fiction
# 2           314        1       5      classics
# 3           314        1       5    paranormal
# 4           314        1       5       mystery
# ...         ...      ...     ...           ...
# 496543    53249     9998       5        horror
# 496544    53249     9998       5  contemporary
# 496545    53249     9998       5    philosophy
# 496546    53249     9998       5        ebooks
# 496547    53249     9998       5       mystery
#
# [496548 rows x 4 columns]

# %%
ratings_sorted = df_fil.sort_values(by='user_id')
ratings_sorted
# Out:
#         user_id  book_id  rating         genre
# 484516        2     9762       4    philosophy
# 484513        2     9762       4    psychology
# 484514        2     9762       4  spirituality
# 484517        2     9762       4      religion
# 484515        2     9762       4    nonfiction
# ...         ...      ...     ...           ...
# 201189    53424     4214       5      classics
# 201188    53424     4214       5       fantasy
# 201195    53424     4214       5        ebooks
# 201196    53424     4214       5        travel
# 201194    53424     4214       5  spirituality
#
# [496548 rows x 4 columns]

# %%
# genres_ratings_sorted= ratings_sorted.rename(columns={'user_index': 'user', 'book_index': 'book_id'})
# genres_ratings_sorted

# %%
grouped_df = ratings_sorted.groupby(['user_id', 'book_id']).agg({'genre': ', '.join, 'rating': 'mean'}).reset_index()
grouped_df
# Out:
#        user_id  book_id                                              genre  \
# 0            2     9762  philosophy, psychology, spirituality, religion...
# 1            3     9014  thriller, fantasy, fiction, horror, ebooks, sc...
# 2            4     3273  ebooks, travel, contemporary, fiction, history...
# 3            7     1519  fantasy, philosophy, history, poetry, fiction,...
# 4            7     3711          religion, classics, contemporary, fiction
# ...        ...      ...                                                ...
# 79526    53420     4625                          ebooks, classics, fiction
# 79527    53420     6538  nonfiction, history, suspense, ebooks, science...
# 79528    53422     7667  suspense, mystery, thriller, fiction, crime, s...
# 79529    53423     4984  classics, fiction, biography, ebooks, science,...
# 79530    53424     4214  religion, fiction, philosophy, contemporary, c...
#
#        rating
# 0         4.0
# 1         1.0
# 2         2.0
# 3         5.0
# 4         5.0
# ...       ...
# 79526     3.0
# 79527     4.0
# 79528     4.0
# 79529     5.0
# 79530     5.0
#
# [79531 rows x 4 columns]

# %%
# Step 1: Filter book_ids with less than 10 ratings
book_counts = grouped_df['book_id'].value_counts()
popular_books = book_counts[book_counts >= 3].index
df_filtered_books = grouped_df[grouped_df['book_id'].isin(popular_books)]

# Step 2: Filter users with less than 20 interactions
user_counts = df_filtered_books['user_id'].value_counts()
active_users = user_counts[user_counts >= 10].index
df_filtered = df_filtered_books[df_filtered_books['user_id'].isin(active_users)]

# Step 3: Reset the indices of the filtered DataFrame
df_filtered.reset_index(drop=True, inplace=True)

# Now, df_filtered contains the data where book_ids have at least 10 ratings, users have at least 20 interactions, and the indices are reset.

# Step 4: Create mapping dictionaries for book_id and user_id to integer indices
book_id_to_index = {book_id: index+1 for index, book_id in enumerate(df_filtered['book_id'].unique())}
user_id_to_index = {user_id: index+1 for index, user_id in enumerate(df_filtered['user_id'].unique())}

# Step 5: Map book_id and user_id to integer indices in the DataFrame
df_filtered['book_index'] = df_filtered['book_id'].map(book_id_to_index)
df_filtered['user_index'] = df_filtered['user_id'].map(user_id_to_index)

# Now, df_filtered contains integer indices for book_id and user_id in the 'book_index' and 'user_index' columns.
df_filtered = df_filtered.rename(columns={'user_index': 'user', 'book_index': 'item'})

# %%
df_filtered.to_csv ("goodbook/V1_RealIDS_ratings_filtered_goodbook.csv", index= False)

# %%
grouped_df = df_filtered[['user', 'item', 'rating', 'genre']]
grouped_df
# Out:
#        user  item  rating                                              genre
# 0         1     1     5.0  classics, fiction, fantasy, contemporary, myst...
# 1         1     2     1.0                 fiction, classics, fantasy, ebooks
# 2         1     3     2.0  classics, science, fiction, fantasy, philosoph...
# 3         1     4     5.0  science, ebooks, religion, philosophy, classic...
# 4         1     5     4.0  ebooks, fiction, classics, contemporary, roman...
# ...     ...   ...     ...                                                ...
# 13187   943    90     5.0  memoir, classics, nonfiction, travel, history,...
# 13188   943    19     5.0  music, fiction, classics, ebooks, history, con...
# 13189   943   109     5.0  classics, ebooks, thriller, mystery, fiction, ...
# 13190   943   110     5.0  mystery, fiction, crime, ebooks, thriller, sus...
# 13191   943   381     5.0           contemporary, history, classics, fiction
#
# [13192 rows x 4 columns]

# %%
# grouped_df= df_filtered.copy()
# Number of unique user_ids and book_ids
num_unique_users = grouped_df['user'].nunique()
num_unique_books = grouped_df['item'].nunique()

# Total possible interactions (assuming all combinations exist)
total_possible_interactions = num_unique_users * num_unique_books

# Actual number of interactions (non-zero ratings)
num_interactions = grouped_df.shape[0]

# Sparsity calculation
sparsity = 1.0 - (num_interactions / total_possible_interactions)

# Print the results
print(f"Number of unique user_ids: {num_unique_users}")
print(f"Number of unique book_ids: {num_unique_books}")
print(f"Sparsity of the data: {sparsity:.4f}")
# Out:
# Number of unique user_ids: 943
# Number of unique book_ids: 761
# Sparsity of the data: 0.9816

# %%
# Group by 'user_id' and count the ratings for each user
user_ratings_counts = grouped_df.groupby('user')['rating'].count()

# Sort the user ratings counts in descending order
sorted_user_ratings_counts = np.sort(user_ratings_counts)[::-1]

# If you want to sort in descending order but preserve the corresponding user IDs:
sorted_user_ids = user_ratings_counts.index[np.argsort(user_ratings_counts.values)[::-1]]

# If you want to see both user IDs and their corresponding counts:
sorted_user_data = pd.DataFrame({'user': sorted_user_ids, 'rating_count': sorted_user_ratings_counts})
sorted_user_data
# Out:
#      user  rating_count
# 0     244            32
# 1     479            32
# 2     650            31
# 3     397            30
# 4     868            30
# ..    ...           ...
# 938   415            10
# 939   216            10
# 940   416            10
# 941   715            10
# 942   194            10
#
# [943 rows x 2 columns]

# %% [markdown]
# # Train / Test Split

# %%
# user_sampling = xf.SampleN(5)

# folds = list(xf.partition_users(grouped_df, 1, xf.SampleN(5)))
# train, test = next(folds)

for i, tp in enumerate(xf.partition_users(grouped_df, 1, xf.SampleN(5))):
  tp.train.to_csv('train-book%d.csv' % (i,), index= False)
  tp.test.to_csv('val-book%d.csv' % (i,), index= False)

# %%
grouped_df.to_csv ("goodbook/ratings_filtered_goodbook.csv", index= False)

# %%
train = pd.read_csv("goodbook/trainVal-book0.csv")
for i, tp in enumerate(xf.partition_users(grouped_df, 1, xf.SampleN(5))):
  tp.train.to_csv('train-book%d.csv' % (i,), index= False)
  tp.test.to_csv('val-book%d.csv' % (i,), index= False)

# %%
grouped_df.to_csv("goodbook/processed_GB_Data.csv", index=False)

# %% [markdown]
# # Recommendation

# %%
# train = pd.read_csv ("goodbook/trainVal-book0.csv", sep=",", names= ["user", "item", "rating", "genre"]) # 
train = pd.read_csv ("goodbook/obfuscated_user_item_matrix_2%_top50Inditems_top100IndiUsers_Categories.csv", sep=",", names= ["user", "item", "rating", "genre"]) # 
# train = pd.read_csv ("goodbook/Adding_user_item_matrix_20%.csv", sep=",", names= ["user", "item", "rating", "genre"]) # 
# val = pd.read_csv ("goodbook/val-book0.csv", sep=",", names= ["user", "item", "rating", "genre"])
test = pd.read_csv ("goodbook/test-book0.csv", sep=",", names= ["user", "item", "rating", "genre"])

# %%
train ["rating"] = 1
train = train [["user", "item", "rating"]] #.copy ()
# trainVal_small.to_csv ("goodbook/trainVal_small.csv", index= False)\

# val_small = train [["user", "item", "rating"]] #.copy ()
# train_small.to_csv ("goodbook/train_small.csv", index= False)
test ["rating"] = 1
test = test [["user", "item", "rating"]] #.copy ()
# test_small.to_csv ("goodbook/test_small.csv", index= False)

# %%
train
# Out:
#       user  item  rating
# 0        1     3       1
# 1        1     4       1
# 2        1     5       1
# 3        1     7       1
# 4        1     8       1
# ...    ...   ...     ...
# 8494   943    90       1
# 8495   943   109       1
# 8496   943   127       1
# 8497   943   381       1
# 8498   943   610       1
#
# [8499 rows x 3 columns]

# %%
test.user.value_counts()
# Out:
# 1      5
# 634    5
# 622    5
# 623    5
# 624    5
#       ..
# 319    5
# 320    5
# 321    5
# 322    5
# 943    5
# Name: user, Length: 943, dtype: int64

# %%
# train
train.user.value_counts()
# Out:
# 427    25
# 921    25
# 811    25
# 645    25
# 790    24
#        ..
# 704     4
# 775     4
# 780     4
# 895     3
# 870     3
# Name: user, Length: 943, dtype: int64

# %%
# len (grouped_df.item.unique ())

# %%
BPR = tf.BPR(features=200, epochs= 500)
# ItemKNN = item_knn.ItemItem (nnbrs=50)
# UserKNN = user_knn.UserUser (nnbrs=50)

# %%
def evaluation(aname, algo, train, test):
    fittable = util.clone(algo)
    fittable = Recommender.adapt(fittable)
    fittable.fit(train)
    users = test.user.unique()
    # now we run the recommender
    recs = batch.recommend(fittable, users, 10)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
all_recs = []
test_data = []
# for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
test_data.append(test)
test_data
# Out:
# [      user  item  rating
#  0        1     2       1
#  1        1     9       1
#  2        1     6       1
#  3        1    12       1
#  4        1     1       1
#  ...    ...   ...     ...
#  4710   943    85       1
#  4711   943   132       1
#  4712   943   110       1
#  4713   943    50       1
#  4714   943    70       1
#
#  [4715 rows x 3 columns]]

# %%
all_recs.append(evaluation('BPR', BPR, train, test))
# all_recs.append(evaluation('ItemKNN', ItemKNN, train, test))
# all_recs.append(evaluation('UserKNN', UserKNN, train, test))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.7131
# Epoch 2/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7121
# Epoch 3/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7102
# Epoch 4/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7088
# Epoch 5/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7073
# Epoch 6/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7055
# Epoch 7/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7041
# Epoch 8/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7026
# Epoch 9/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7012
# Epoch 10/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6999
# Epoch 11/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6981
# Epoch 12/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6968
# Epoch 13/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6950
# Epoch 14/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6934
# Epoch 15/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6920
# Epoch 16/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6906
# Epoch 17/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6891
# Epoch 18/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6874
# Epoch 19/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6863
# Epoch 20/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6844
# Epoch 21/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6836
# Epoch 22/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6819
# Epoch 23/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6803
# Epoch 24/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6787
# Epoch 25/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6773
# Epoch 26/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6761
# Epoch 27/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6743
# Epoch 28/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6725
# Epoch 29/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6710
# Epoch 30/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6698
# Epoch 31/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6683
# Epoch 32/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6660
# Epoch 33/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6651
# Epoch 34/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6639
# Epoch 35/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6620
# Epoch 36/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6598
# Epoch 37/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6586
# Epoch 38/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6571
# Epoch 39/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6552
# Epoch 40/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6530
# Epoch 41/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6519
# Epoch 42/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6499
# Epoch 43/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6482
# Epoch 44/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6460
# Epoch 45/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6442
# Epoch 46/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6424
# Epoch 47/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6407
# Epoch 48/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6385
# Epoch 49/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6363
# Epoch 50/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6346
# Epoch 51/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6321
# Epoch 52/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6301
# Epoch 53/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6281
# Epoch 54/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6260
# Epoch 55/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6236
# Epoch 56/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6217
# Epoch 57/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6190
# Epoch 58/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6168
# Epoch 59/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6144
# Epoch 60/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6122
# Epoch 61/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6096
# Epoch 62/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6068
# Epoch 63/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6044
# Epoch 64/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6018
# Epoch 65/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5992
# Epoch 66/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5961
# Epoch 67/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5939
# Epoch 68/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5911
# Epoch 69/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5884
# Epoch 70/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5858
# Epoch 71/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5824
# Epoch 72/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5799
# Epoch 73/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5766
# Epoch 74/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5735
# Epoch 75/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5707
# Epoch 76/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5680
# Epoch 77/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5644
# Epoch 78/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5619
# Epoch 79/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5579
# Epoch 80/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5549
# Epoch 81/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5520
# Epoch 82/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5492
# Epoch 83/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5460
# Epoch 84/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5417
# Epoch 85/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5389
# Epoch 86/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5354
# Epoch 87/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5317
# Epoch 88/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5290
# Epoch 89/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5244
# Epoch 90/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5206
# Epoch 91/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5187
# Epoch 92/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5141
# Epoch 93/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5107
# Epoch 94/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5086
# Epoch 95/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5045
# Epoch 96/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5010
# Epoch 97/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4951
# Epoch 98/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4931
# Epoch 99/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4897
# Epoch 100/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4869
# Epoch 101/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4840
# Epoch 102/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4790
# Epoch 103/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4767
# Epoch 104/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4726
# Epoch 105/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4691
# Epoch 106/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4655
# Epoch 107/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4623
# Epoch 108/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4594
# Epoch 109/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4543
# Epoch 110/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4535
# Epoch 111/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4484
# Epoch 112/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4465
# Epoch 113/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4430
# Epoch 114/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4396
# Epoch 115/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4374
# Epoch 116/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4317
# Epoch 117/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4283
# Epoch 118/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4250
# Epoch 119/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4223
# Epoch 120/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4205
# Epoch 121/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4166
# Epoch 122/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4139
# Epoch 123/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4104
# Epoch 124/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4073
# Epoch 125/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4060
# Epoch 126/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4010
# Epoch 127/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4013
# Epoch 128/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3955
# Epoch 129/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3938
# Epoch 130/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3915
# Epoch 131/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3894
# Epoch 132/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3843
# Epoch 133/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3833
# Epoch 134/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3795
# Epoch 135/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3790
# Epoch 136/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3783
# Epoch 137/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3748
# Epoch 138/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3709
# Epoch 139/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3710
# Epoch 140/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3658
# Epoch 141/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3629
# Epoch 142/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3618
# Epoch 143/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3610
# Epoch 144/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3587
# Epoch 145/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3573
# Epoch 146/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3535
# Epoch 147/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3517
# Epoch 148/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3507
# Epoch 149/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3455
# Epoch 150/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3451
# Epoch 151/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3446
# Epoch 152/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3401
# Epoch 153/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3425
# Epoch 154/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3372
# Epoch 155/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3363
# Epoch 156/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3344
# Epoch 157/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3348
# Epoch 158/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3300
# Epoch 159/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3302
# Epoch 160/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3278
# Epoch 161/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3251
# Epoch 162/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3246
# Epoch 163/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3230
# Epoch 164/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3204
# Epoch 165/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3193
# Epoch 166/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3202
# Epoch 167/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3170
# Epoch 168/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3151
# Epoch 169/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3153
# Epoch 170/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3130
# Epoch 171/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3118
# Epoch 172/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3100
# Epoch 173/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3073
# Epoch 174/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3071
# Epoch 175/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3066
# Epoch 176/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3047
# Epoch 177/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3056
# Epoch 178/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3042
# Epoch 179/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3015
# Epoch 180/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3018
# Epoch 181/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2990
# Epoch 182/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2972
# Epoch 183/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2971
# Epoch 184/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2939
# Epoch 185/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2947
# Epoch 186/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2942
# Epoch 187/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2927
# Epoch 188/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2939
# Epoch 189/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2922
# Epoch 190/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2937
# Epoch 191/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2903
# Epoch 192/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2864
# Epoch 193/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2874
# Epoch 194/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2863
# Epoch 195/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2853
# Epoch 196/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2871
# Epoch 197/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2849
# Epoch 198/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2840
# Epoch 199/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2834
# Epoch 200/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2812
# Epoch 201/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2815
# Epoch 202/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2804
# Epoch 203/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2798
# Epoch 204/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2811
# Epoch 205/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2791
# Epoch 206/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2792
# Epoch 207/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2782
# Epoch 208/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2755
# Epoch 209/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2780
# Epoch 210/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2768
# Epoch 211/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2745
# Epoch 212/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2730
# Epoch 213/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2740
# Epoch 214/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2725
# Epoch 215/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2721
# Epoch 216/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2727
# Epoch 217/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2725
# Epoch 218/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2715
# Epoch 219/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2698
# Epoch 220/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2692
# Epoch 221/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2687
# Epoch 222/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2695
# Epoch 223/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2700
# Epoch 224/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2681
# Epoch 225/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2651
# Epoch 226/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2671
# Epoch 227/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2674
# Epoch 228/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2644
# Epoch 229/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2680
# Epoch 230/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2666
# Epoch 231/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2644
# Epoch 232/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2639
# Epoch 233/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2636
# Epoch 234/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2639
# Epoch 235/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2626
# Epoch 236/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2621
# Epoch 237/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2620
# Epoch 238/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2606
# Epoch 239/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2618
# Epoch 240/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2619
# Epoch 241/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2605
# Epoch 242/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2591
# Epoch 243/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2604
# Epoch 244/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2601
# Epoch 245/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2592
# Epoch 246/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2583
# Epoch 247/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2571
# Epoch 248/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2575
# Epoch 249/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2576
# Epoch 250/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2568
# Epoch 251/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2577
# Epoch 252/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2552
# Epoch 253/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2570
# Epoch 254/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2546
# Epoch 255/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2556
# Epoch 256/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2556
# Epoch 257/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2561
# Epoch 258/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2540
# Epoch 259/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2542
# Epoch 260/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2548
# Epoch 261/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2557
# Epoch 262/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2551
# Epoch 263/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2534
# Epoch 264/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2559
# Epoch 265/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2546
# Epoch 266/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2533
# Epoch 267/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2542
# Epoch 268/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2529
# Epoch 269/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2529
# Epoch 270/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2519
# Epoch 271/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2535
# Epoch 272/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2521
# Epoch 273/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2521
# Epoch 274/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2516
# Epoch 275/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2509
# Epoch 276/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2518
# Epoch 277/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2491
# Epoch 278/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2497
# Epoch 279/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2495
# Epoch 280/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2510
# Epoch 281/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2490
# Epoch 282/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2494
# Epoch 283/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2504
# Epoch 284/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2481
# Epoch 285/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2494
# Epoch 286/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2504
# Epoch 287/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2478
# Epoch 288/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2481
# Epoch 289/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2474
# Epoch 290/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2474
# Epoch 291/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2472
# Epoch 292/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2500
# Epoch 293/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2473
# Epoch 294/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2481
# Epoch 295/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2481
# Epoch 296/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2467
# Epoch 297/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2455
# Epoch 298/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2470
# Epoch 299/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2460
# Epoch 300/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2469
# Epoch 301/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2451
# Epoch 302/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2448
# Epoch 303/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2453
# Epoch 304/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2450
# Epoch 305/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2445
# Epoch 306/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2450
# Epoch 307/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2454
# Epoch 308/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2437
# Epoch 309/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2447
# Epoch 310/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2451
# Epoch 311/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2435
# Epoch 312/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2445
# Epoch 313/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2447
# Epoch 314/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2437
# Epoch 315/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2444
# Epoch 316/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2454
# Epoch 317/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2438
# Epoch 318/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2435
# Epoch 319/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2455
# Epoch 320/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2443
# Epoch 321/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2443
# Epoch 322/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2423
# Epoch 323/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2428
# Epoch 324/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2424
# Epoch 325/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2452
# Epoch 326/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2435
# Epoch 327/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2427
# Epoch 328/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2432
# Epoch 329/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2429
# Epoch 330/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2431
# Epoch 331/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2416
# Epoch 332/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2425
# Epoch 333/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2424
# Epoch 334/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2426
# Epoch 335/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2424
# Epoch 336/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2414
# Epoch 337/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2427
# Epoch 338/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2436
# Epoch 339/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2403
# Epoch 340/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2412
# Epoch 341/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2411
# Epoch 342/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2408
# Epoch 343/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2407
# Epoch 344/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2399
# Epoch 345/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2405
# Epoch 346/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2402
# Epoch 347/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2413
# Epoch 348/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2402
# Epoch 349/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2397
# Epoch 350/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2404
# Epoch 351/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2403
# Epoch 352/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2406
# Epoch 353/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2400
# Epoch 354/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2389
# Epoch 355/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2398
# Epoch 356/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2392
# Epoch 357/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2398
# Epoch 358/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2398
# Epoch 359/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2414
# Epoch 360/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2395
# Epoch 361/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2404
# Epoch 362/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2391
# Epoch 363/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2387
# Epoch 364/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2390
# Epoch 365/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2386
# Epoch 366/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2389
# Epoch 367/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2394
# Epoch 368/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2398
# Epoch 369/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2380
# Epoch 370/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2384
# Epoch 371/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2416
# Epoch 372/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2388
# Epoch 373/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2393
# Epoch 374/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2377
# Epoch 375/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2383
# Epoch 376/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2402
# Epoch 377/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2386
# Epoch 378/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2375
# Epoch 379/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2380
# Epoch 380/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2374
# Epoch 381/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2379
# Epoch 382/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2393
# Epoch 383/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2392
# Epoch 384/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2379
# Epoch 385/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2368
# Epoch 386/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2385
# Epoch 387/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2381
# Epoch 388/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2370
# Epoch 389/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2386
# Epoch 390/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2371
# Epoch 391/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2368
# Epoch 392/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2369
# Epoch 393/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2365
# Epoch 394/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2371
# Epoch 395/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2371
# Epoch 396/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2371
# Epoch 397/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2372
# Epoch 398/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2371
# Epoch 399/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2364
# Epoch 400/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2366
# Epoch 401/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2366
# Epoch 402/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2368
# Epoch 403/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2362
# Epoch 404/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2370
# Epoch 405/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2377
# Epoch 406/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2357
# Epoch 407/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2355
# Epoch 408/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2363
# Epoch 409/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2360
# Epoch 410/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2382
# Epoch 411/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2348
# Epoch 412/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2361
# Epoch 413/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2363
# Epoch 414/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2369
# Epoch 415/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2354
# Epoch 416/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2365
# Epoch 417/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2348
# Epoch 418/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2345
# Epoch 419/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2345
# Epoch 420/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2353
# Epoch 421/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2360
# Epoch 422/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2359
# Epoch 423/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2350
# Epoch 424/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2355
# Epoch 425/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2351
# Epoch 426/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2357
# Epoch 427/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2357
# Epoch 428/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2370
# Epoch 429/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2345
# Epoch 430/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2343
# Epoch 431/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2349
# Epoch 432/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2353
# Epoch 433/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2342
# Epoch 434/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2351
# Epoch 435/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2345
# Epoch 436/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2351
# Epoch 437/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2345
# Epoch 438/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2343
# Epoch 439/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2331
# Epoch 440/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2344
# Epoch 441/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2345
# Epoch 442/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2331
# Epoch 443/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2347
# Epoch 444/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2331
# Epoch 445/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2341
# Epoch 446/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2344
# Epoch 447/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2325
# Epoch 448/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2336
# Epoch 449/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2333
# Epoch 450/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2345
# Epoch 451/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2330
# Epoch 452/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2334
# Epoch 453/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2328
# Epoch 454/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2342
# Epoch 455/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2324
# Epoch 456/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2338
# Epoch 457/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2327
# Epoch 458/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2345
# Epoch 459/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2329
# Epoch 460/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2337
# Epoch 461/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2329
# Epoch 462/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2323
# Epoch 463/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2333
# Epoch 464/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2335
# Epoch 465/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2346
# Epoch 466/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2340
# Epoch 467/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2339
# Epoch 468/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2336
# Epoch 469/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2325
# Epoch 470/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2330
# Epoch 471/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2335
# Epoch 472/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2336
# Epoch 473/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2333
# Epoch 474/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2327
# Epoch 475/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2334
# Epoch 476/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2331
# Epoch 477/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2326
# Epoch 478/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2322
# Epoch 479/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2331
# Epoch 480/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2333
# Epoch 481/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2322
# Epoch 482/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2337
# Epoch 483/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2333
# Epoch 484/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2327
# Epoch 485/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2325
# Epoch 486/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2326
# Epoch 487/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2325
# Epoch 488/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2314
# Epoch 489/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2322
# Epoch 490/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2337
# Epoch 491/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2308
# Epoch 492/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2314
# Epoch 493/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2330
# Epoch 494/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2337
# Epoch 495/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2329
# Epoch 496/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2320
# Epoch 497/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2317
# Epoch 498/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2321
# Epoch 499/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2309
# Epoch 500/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2321

# %%
all_recs = pd.concat(all_recs, ignore_index=True)
all_recs.head()
# Out:
#    item     score  user  rank Algorithm
# 0   158  2.127220     1     1       BPR
# 1    75  2.049705     1     2       BPR
# 2    80  1.879437     1     3       BPR
# 3    81  1.878907     1     4       BPR
# 4    62  1.738119     1     5       BPR

# %%
# all_recs.to_csv ("all_recs_BPR")

# %%
all_recs_df = all_recs.copy ()

# %%
test_data = []
test_data.append(test)

# %%
test_data = pd.concat(test_data, ignore_index=True)

# %%
rla = topn.RecListAnalysis()
rla.add_metric(topn.ndcg)
rla.add_metric(topn.hit)
rla.add_metric(topn.precision)
rla.add_metric(topn.recall)

results = rla.compute(all_recs_df, test_data) # all_recs
results.head()
# Out:
#                 nrecs      ndcg  hit  precision  recall
# Algorithm user
# BPR       1        10  0.100013  1.0        0.1     0.2
#           2        10  0.093591  1.0        0.1     0.2
#           3        10  0.120922  1.0        0.1     0.2
#           4        10  0.561544  1.0        0.2     0.4
#           5        10  0.084521  1.0        0.1     0.2

# %%
results.groupby('Algorithm').mean()
# Out:
#            nrecs      ndcg       hit  precision    recall
# Algorithm
# BPR         10.0  0.227129  0.702015   0.126723  0.253446

# %%
# results.to_csv ("/Users/mslokom/Documents/RecSys_News/goodbook/results_BPR_fullObf_p5%.csv")

# %% [markdown]
# # Clean the dataset <a id="2"></a> <br>
#
# As with nearly any real-life dataset, we need to do some cleaning first. When exploring the data I noticed that for some combinations of user and book there are multiple ratings, while in theory there should only be one (unless users can rate a book several times). Furthermore, for the collaborative filtering it is better to have more ratings per user. So I decided to remove users who have rated fewer than 3 books.

# %%
# books['original_publication_year'] = books['original_publication_year'].fillna(-1).apply(lambda x: int(x) if x != -1 else -1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mslokom/Documents/RecSys_News/goodreads-2-book-recommender-system.ipynb Cell 55 line 1
# ----> <a href='vscode-notebook-cell:/Users/mslokom/Documents/RecSys_News/goodreads-2-book-recommender-system.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> books['original_publication_year'] = books['original_publication_year'].fillna(-1).apply(lambda x: int(x) if x != -1 else -1)
#
# NameError: name 'books' is not defined

# %%
ratings_rmv_duplicates = ratings.drop_duplicates()
unwanted_users = ratings_rmv_duplicates.groupby('user_id')['user_id'].count()
unwanted_users = unwanted_users[unwanted_users < 3]
unwanted_ratings = ratings_rmv_duplicates[ratings_rmv_duplicates.user_id.isin(unwanted_users.index)]
new_ratings = ratings_rmv_duplicates.drop(unwanted_ratings.index)

# %%
# new_ratings['title'] = books.set_index('id').title.loc[new_ratings.book_id].values

# %%
# new_ratings.head(10)

# %% [markdown]
# # Simple Recommender <a id="3"></a> <br>
#
# The Simple Recommender offers generalized recommnendations to every user based on book popularity and (sometimes) genre. The basic idea behind this recommender is that books that are more popular and more critically acclaimed will have a higher probability of being liked by the average audience. This model does not give personalized recommendations based on the user.
#
# The implementation of this model is extremely trivial. All we have to do is sort our books based on ratings and popularity and display the top books of our list. As an added step, we can pass in a genre argument to get the top books of a particular genre.

# %% [markdown]
# I will use IMDB's *weighted rating* formula to construct my chart. Mathematically, it is represented as follows:
#
# Weighted Rating (WR) = $(\frac{v}{v + m} . R) + (\frac{m}{v + m} . C)$
#
# where,
# * *v* is the number of ratings for the book
# * *m* is the minimum ratings required to be listed in the chart
# * *R* is the average rating of the book
# * *C* is the mean rating across the whole report
#
# The next step is to determine an appropriate value for *m*, the minimum ratings required to be listed in the chart. We will use **95th percentile** as our cutoff. In other words, for a book to feature in the charts, it must have more ratings than at least 95% of the books in the list.
#
# I will build our overall Top 250 Chart and will define a function to build charts for a particular genre. Let's begin!

# %%
# v = books['ratings_count']
# m = books['ratings_count'].quantile(0.95)
# R = books['average_rating']
# C = books['average_rating'].mean()
# W = (R*v + C*m) / (v + m)

# %%
# books['weighted_rating'] = W

# %%
# qualified  = books.sort_values('weighted_rating', ascending=False).head(250)

# %% [markdown]
# ## Top Books <a id="4"></a> <br>

# %%
# qualified[['title', 'authors', 'average_rating', 'weighted_rating']].head(15)

# %% [markdown]
# We see that J.K. Rowling's **Harry Potter** Books occur at the very top of our chart. The chart also indicates a strong bias of Goodreads Users towards particular genres and authors.
#
# Let us now construct our function that builds charts for particular genres. For this, we will use relax our default conditions to the **85th** percentile instead of 95.

# %% [markdown]
# ## Top "Genres" Books <a id="5"></a> <br>

# %%
# book_tags.head()

# %%
# tags.head()

# %%
# genres = ["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics",
#           "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction",
#           "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror",
#           "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal",
#           "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction", 
#           "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

# %%
# genres = list(map(str.lower, genres))
# genres[:4]

# %%
# available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]

# %%
# available_genres.head()

# %%
# available_genres_books = book_tags[book_tags.tag_id.isin(available_genres.tag_id)]

# %%
# print('There are {} books that are tagged with above genres'.format(available_genres_books.shape[0]))

# %%
# available_genres_books.head()

# %%
# len (available_genres_books.goodreads_book_id.unique())

# %%
# available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values
# available_genres_books.head()

# %%
# def build_chart(genre, percentile=0.85):
#     df = available_genres_books[available_genres_books['genre'] == genre.lower()]
#     qualified = books.set_index('book_id').loc[df.goodreads_book_id]

#     v = qualified['ratings_count']
#     m = qualified['ratings_count'].quantile(percentile)
#     R = qualified['average_rating']
#     C = qualified['average_rating'].mean()
#     qualified['weighted_rating'] = (R*v + C*m) / (v + m)

#     qualified.sort_values('weighted_rating', ascending=False, inplace=True)
#     return qualified

# %% [markdown]
# Let us see our method in action by displaying the Top 15 Fiction Books (Fiction almost didn't feature at all in our Generic Top Chart despite being one of the most popular movie genres).

# %%
# cols = ['title','authors','original_publication_year','average_rating','ratings_count','work_text_reviews_count','weighted_rating']

# %%
# genre = 'Fiction'
# build_chart(genre)[cols].head(15)

# %% [markdown]
# For simplicity, you can just pass the index of the wanted genre from below.

# %%
# list(enumerate(available_genres.tag_name))

# %%
# idx = 24  # romance
# build_chart(list(available_genres.tag_name)[idx])[cols].head(15)

# %% [markdown]
# # Content Based Recommender <a id="6"></a> <br>
#
# ![](https://miro.medium.com/max/828/1*1b-yMSGZ1HfxvHiJCiPV7Q.png)
#
# The recommender we built in the previous section suffers some severe limitations. For one, it gives the same recommendation to everyone, regardless of the user's personal taste. If a person who loves business books (and hates fiction) were to look at our Top 15 Chart, s/he wouldn't probably like most of the books. If s/he were to go one step further and look at our charts by genre, s/he wouldn't still be getting the best recommendations.
#
# For instance, consider a person who loves *The Fault in Our Stars*, *Twilight*. One inference we can obtain is that the person loves the romaintic books. Even if s/he were to access the romance chart, s/he wouldn't find these as the top recommendations.
#
# To personalise our recommendations more, I am going to build an engine that computes similarity between movies based on certain metrics and suggests books that are most similar to a particular book that a user liked. Since we will be using book metadata (or content) to build this engine, this also known as **Content Based Filtering.**
#
# I will build this recommender based on book's *Title*, *Authors* and *Genres*.

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %% [markdown]
# My approach to building the recommender is going to be extremely *hacky*. These are steps I plan to do:
# 1. **Strip Spaces and Convert to Lowercase** from authors. This way, our engine will not confuse between **Stephen Covey** and **Stephen King**.
# 2. Combining books with their corresponding **genres** .
# 2. I then use a **Count Vectorizer** to create our count matrix.
#
# Finally, we calculate the cosine similarities and return books that are most similar.

# %%
# books['authors'] = books['authors'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x.split(', ')])

# %%
# def get_genres(x):
#     t = book_tags[book_tags.goodreads_book_id==x]
#     return [i.lower().replace(" ", "") for i in tags.tag_name.loc[t.tag_id].values]

# %%
# books['genres'] = books.book_id.apply(get_genres)

# %%
# books['soup'] = books.apply(lambda x: ' '.join([x['title']] + x['authors'] + x['genres']), axis=1)

# %%
# books.soup.head()

# %%
# count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0.0, stop_words='english')
# count_matrix = count.fit_transform(books['soup'])

# %% [markdown]
# ## Cosine Similarity <a id="7"></a> <br>
#
# I will be using the Cosine Similarity to calculate a numeric quantity that denotes the similarity between two books. Mathematically, it is defined as follows:
#
# $cosine(x,y) = \frac{x. y^\intercal}{||x||.||y||} $

# %%
# cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# indices = pd.Series(books.index, index=books['title'])
# titles = books['title']

# %%
# def get_recommendations(title, n=10):
#     idx = indices[title]
#     sim_scores = list(enumerate(cosine_sim[idx]))
#     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#     sim_scores = sim_scores[1:31]
#     book_indices = [i[0] for i in sim_scores]
#     return list(titles.iloc[book_indices].values)[:n]

# %%
# get_recommendations("The One Minute Manager")

# %% [markdown]
# What if I want a specific book but I can't remember it's full name!!
#
# So I created the following *method* to get book titles from a **partial** title.

# %%
# def get_name_from_partial(title):
#     return list(books.title[books.title.str.lower().str.contains(title) == True].values)

# %%
# title = "business"
# l = get_name_from_partial(title)
# list(enumerate(l))

# %%
# get_recommendations(l[1])

# %% [markdown]
# ## Popularity and Ratings <a id="8"></a> <br>
#
# One thing that we notice about our recommendation system is that it recommends books regardless of ratings and popularity. It is true that ***Across the River and Into the Trees*** and ***The Old Man and the Sea*** were written by **Ernest Hemingway**, but the former one was cnosidered a bad (not the worst) book that shouldn't be recommended to anyone, since that most people hated the book for it's static plot and overwrought emotion.
#
# Therefore, we will add a mechanism to remove bad books and return books which are popular and have had a good critical response.
#
# I will take the top 30 movies based on similarity scores and calculate the vote of the 60th percentile book. Then, using this as the value of $m$, we will calculate the weighted rating of each book using IMDB's formula like we did in the Simple Recommender section.

# %%
# def improved_recommendations(title, n=10):
#     idx = indices[title]
#     sim_scores = list(enumerate(cosine_sim[idx]))
#     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#     sim_scores = sim_scores[1:31]
#     book_indices = [i[0] for i in sim_scores]
#     df = books.iloc[book_indices][['title', 'ratings_count', 'average_rating', 'weighted_rating']]

#     v = df['ratings_count']
#     m = df['ratings_count'].quantile(0.60)
#     R = df['average_rating']
#     C = df['average_rating'].mean()
#     df['weighted_rating'] = (R*v + C*m) / (v + m)
    
#     qualified = df[df['ratings_count'] >= m]
#     qualified = qualified.sort_values('weighted_rating', ascending=False)
#     return qualified.head(n)

# %%
# improved_recommendations("The One Minute Manager")

# %%
# improved_recommendations(l[1])

# %% [markdown]
# I think the sorting of similar is more better now than before.
# Therefore, we will conclude our Content Based Recommender section here and come back to it when we build a hybrid engine.

# %% [markdown]
# # Collaborative Filtering <a id="9"></a> <br>
#
# ![](https://miro.medium.com/max/706/1*DYJ-HQnOVvmm5suNtqV3Jw.png)
#
# Our content based engine suffers from some severe limitations. It is only capable of suggesting books which are *close* to a certain book. That is, it is not capable of capturing tastes and providing recommendations across genres.
#
# Also, the engine that we built is not really personal in that it doesn't capture the personal tastes and biases of a user. Anyone querying our engine for recommendations based on a book will receive the same recommendations for that book, regardless of who s/he is.
#
# Therefore, in this section, we will use a technique called **Collaborative Filtering** to make recommendations to Book Readers. Collaborative Filtering is based on the idea that users similar to a me can be used to predict how much I will like a particular product or service those users have used/experienced but I have not.
#
# I will not be implementing Collaborative Filtering from scratch. Instead, I will use the **Surprise** library that used extremely powerful algorithms like **Singular Value Decomposition (SVD)** to minimise RMSE (Root Mean Square Error) and give great recommendations.

# %% [markdown]
# There are two classes of Collaborative Filtering:
# ![](https://miro.medium.com/max/1280/1*QvhetbRjCr1vryTch_2HZQ.jpeg)
# - **User-based**, which measures the similarity between target users and other users.
# - **Item-based**, which measures the similarity between the items that target users rate or interact with and other items.

# %% [markdown]
# ## - User Based <a id="10"></a> <br>

# %%
# ! pip install surprise

# %%
# from surprise import Reader, Dataset, SVD
# from surprise.model_selection import cross_validate

# %%
# reader = Reader()
# data = Dataset.load_from_df(new_ratings[['user_id', 'book_id', 'rating']], reader)
